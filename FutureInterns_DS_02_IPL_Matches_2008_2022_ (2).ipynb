# %%
#Import Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set the style for seaborn
sns.set(style="whitegrid")

# %%
# LOADING THE LOAN DATASE
IPL_MATCHES = pd.read_csv('IPL_MATCHES.csv')  
IPL_MATCHES
# Out:
#           id        city  match_date   season match_number  \
# 0    1312200   Ahmedabad  29-05-2022     2022        Final
# 1    1312199   Ahmedabad  27-05-2022     2022  Qualifier 2
# 2    1312198     Kolkata  25-05-2022     2022   Eliminator
# 3    1312197     Kolkata  24-05-2022     2022  Qualifier 1
# 4    1304116      Mumbai  22-05-2022     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  20-04-2008  2007/08            4
# 946   335985      Mumbai  20-04-2008  2007/08            5
# 947   335984       Delhi  19-04-2008  2007/08            3
# 948   335983  Chandigarh  19-04-2008  2007/08            2
# 949   335982   Bangalore  18-04-2008  2007/08            1
#
#                            team1                        team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           venue                  toss_winner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     toss_decision superover                 winning_team   won_by  margin  \
# 0             bat         N               Gujarat Titans  Wickets     7.0
# 1           field         N             Rajasthan Royals  Wickets     7.0
# 2           field         N  Royal Challengers Bangalore     Runs    14.0
# 3           field         N               Gujarat Titans  Wickets     7.0
# 4             bat         N                 Punjab Kings  Wickets     5.0
# ..            ...       ...                          ...      ...     ...
# 945           bat         N        Kolkata Knight Riders  Wickets     5.0
# 946           bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947           bat         N             Delhi Daredevils  Wickets     9.0
# 948           bat         N          Chennai Super Kings     Runs    33.0
# 949         field         N        Kolkata Knight Riders     Runs   140.0
#
#     method player_of_match        umpire1         umpire2
# 0      NaN       HH Pandya    CB Gaffaney     Nitin Menon
# 1      NaN      JC Buttler    CB Gaffaney     Nitin Menon
# 2      NaN      RM Patidar  J Madanagopal        MA Gough
# 3      NaN       DA Miller   BNJ Oxenford       VK Sharma
# 4      NaN   Harpreet Brar   AK Chaudhary   NA Patwardhan
# ..     ...             ...            ...             ...
# 945    NaN       DJ Hussey      BF Bowden     K Hariharan
# 946    NaN      MV Boucher       SJ Davis       DJ Harper
# 947    NaN     MF Maharoof      Aleem Dar  GA Pratapkumar
# 948    NaN      MEK Hussey      MR Benson      SL Shastri
# 949    NaN     BB McCullum      Asad Rauf     RE Koertzen
#
# [950 rows x 18 columns]

# %%
# Preview the loan Data
IPL_MATCHES.head()
# Out:
#         id       city  match_date season match_number  \
# 0  1312200  Ahmedabad  29-05-2022   2022        Final
# 1  1312199  Ahmedabad  27-05-2022   2022  Qualifier 2
# 2  1312198    Kolkata  25-05-2022   2022   Eliminator
# 3  1312197    Kolkata  24-05-2022   2022  Qualifier 1
# 4  1304116     Mumbai  22-05-2022   2022           70
#
#                          team1                 team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               venue           toss_winner toss_decision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals           bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals         field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants         field
# 3             Eden Gardens, Kolkata        Gujarat Titans         field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad           bat
#
#   superover                 winning_team   won_by  margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   player_of_match        umpire1        umpire2
# 0       HH Pandya    CB Gaffaney    Nitin Menon
# 1      JC Buttler    CB Gaffaney    Nitin Menon
# 2      RM Patidar  J Madanagopal       MA Gough
# 3       DA Miller   BNJ Oxenford      VK Sharma
# 4   Harpreet Brar   AK Chaudhary  NA Patwardhan

# %%
# DATA EXPLORATION 
# Checking for Missing Values
IPL_MATCHES.isnull().sum()
# Out:
# id                 0
# city               0
# match_date         0
# season             0
# match_number       0
# team1              0
# team2              0
# venue              0
# toss_winner        0
# toss_decision      0
# superover          0
# winning_team       0
# won_by             0
# margin             0
# method             0
# player_of_match    0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
#HANDLING OF MISSING VALUES

# %%
#HANDLING OF MISSING VALUES FOR CITY
IPL_MATCHES['city'].fillna('mode',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13160\2527787717.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   IPL_MATCHES['city'].fillna('mode',inplace=True)

# %%
#HANDLING OF MISSING VALUES FOR MARGIN
IPL_MATCHES['margin'].fillna(IPL_MATCHES['margin'].median,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13160\984886582.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.median of 0        7.0
# 1        7.0
# 2       14.0
# 3        7.0
# 4        5.0
#        ...
# 945      5.0
# 946      5.0
# 947      9.0
# 948     33.0
# 949    140.0
# Name: margin, Length: 950, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   IPL_MATCHES['margin'].fillna(IPL_MATCHES['margin'].median,inplace=True)

# %%
#HANDLING OF MISSING VALUES FOR METHOD
IPL_MATCHES['method'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13160\3779939991.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   IPL_MATCHES['method'].fillna('Unknown',inplace=True)

# %%
#HANDLING OF MISSING VALUES FOR SUPEROVER
IPL_MATCHES['superover'].fillna('mode',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13160\1654401156.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   IPL_MATCHES['superover'].fillna('mode',inplace=True)

# %%
#HANDLING OF MISSING VALUES FOR PLAYER_OF_MATCH
IPL_MATCHES['player_of_match'].fillna('mode',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13160\3499234198.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   IPL_MATCHES['player_of_match'].fillna('mode',inplace=True)

# %%
#HANDLING OF MISSING VALUES FOR WINNING_TEAM
IPL_MATCHES['winning_team'].fillna('Mode',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13160\188030993.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   IPL_MATCHES['winning_team'].fillna('Mode',inplace=True)

# %%
# Count the number of matches won by each team
matches_won = IPL_MATCHES['winning_team'].value_counts()
print(matches_won)
# Out:
# winning_team
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Mode                             4
# Name: count, dtype: int64

# %%
# Data Visualization : Number of Matches Won by Each Team
plt.figure(figsize=(12, 6))
sns.histplot(IPL_MATCHES['margin'], bins=30, kde=True)
plt.title('Number of Matches Won by Each Team (2008-2022)')
plt.ylabel('Number of Wins')
plt.xlabel('Teams')
plt.show()

# %%
# Visualization
# Distribution of Runs Scored in Matches
# Set the style for seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
sns.countplot(IPL_MATCHES['margin'], bins=30, kde=True)
plt.title('Distribution of Winning Margins in IPL_MATCHES')
plt.xlabel('Winning Margin (Runs/Wickets)')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualization 
#Player of the Match Frequency
player_of_match_counts = IPL_MATCHES['player_of_match'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=player_of_match_counts.values, y=player_of_match_counts.index)
plt.title('Top 10 Players of the Match (2008-2022)')
plt.xlabel('Number of Times Awarded')
plt.ylabel('Player')
plt.show()

# %%
# Visualization 
#Player of the Match Frequency
player_of_match_counts = IPL_MATCHES['player_of_match'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.histplot(x=player_of_match_counts.values, y=player_of_match_counts.index)
plt.title('Top 10 Players of the Match (2008-2022)')
plt.xlabel('Number of Times Awarded')
plt.ylabel('Player')
plt.show()

# %%
# Visualization 
#Player of the Match Frequency
player_of_match_counts = IPL_MATCHES['player_of_match'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.lineplot(x=player_of_match_counts.values, y=player_of_match_counts.index)
plt.title('Top 10 Players of the Match (2008-2022)')
plt.xlabel('Number of Times Awarded')
plt.ylabel('Player')
plt.show()
